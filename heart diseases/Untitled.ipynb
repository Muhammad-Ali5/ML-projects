# %% [markdown]
# # import all Dependencies

# %%
import numpy as np 
import pandas as pd 

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# %% [markdown]
# # Data Collection

# %%
heart_data = pd.read_csv("heart_statlog_cleveland_hungary_final.csv")

# %%
heart_data.head(5)
# Out:
#    age  sex  chest pain type  resting bp s  cholesterol  ...  max heart rate  exercise angina  oldpeak  ST slope  target
# 0   40    1                2           140          289  ...             172                0      0.0         1       0
# 1   49    0                3           160          180  ...             156                0      1.0         2       1
# 2   37    1                2           130          283  ...              98                0      0.0         1       0
# 3   48    0                4           138          214  ...             108                1      1.5         2       1
# 4   54    1                3           150          195  ...             122                0      0.0         1       0
#
# [5 rows x 12 columns]

# %%
heart_data.shape
# Out:
# (1190, 12)

# %%
heart_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1190 entries, 0 to 1189
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   age                  1190 non-null   int64
#  1   sex                  1190 non-null   int64
#  2   chest pain type      1190 non-null   int64
#  3   resting bp s         1190 non-null   int64
#  4   cholesterol          1190 non-null   int64
#  5   fasting blood sugar  1190 non-null   int64
#  6   resting ecg          1190 non-null   int64
#  7   max heart rate       1190 non-null   int64
#  8   exercise angina      1190 non-null   int64
#  9   oldpeak              1190 non-null   float64
#  10  ST slope             1190 non-null   int64
#  11  target               1190 non-null   int64
# dtypes: float64(1), int64(11)
# memory usage: 111.7 KB

# %%
heart_data.isnull().sum()
# Out:
# age                    0
# sex                    0
# chest pain type        0
# resting bp s           0
# cholesterol            0
# fasting blood sugar    0
# resting ecg            0
# max heart rate         0
# exercise angina        0
# oldpeak                0
# ST slope               0
# target                 0
# dtype: int64

# %%
heart_data = heart_data.dropna()

# %%
# statistical measure about data 
heart_data.describe()
# Out:
#                age          sex  chest pain type  resting bp s  ...  exercise angina      oldpeak     ST slope       target
# count  1190.000000  1190.000000      1190.000000   1190.000000  ...      1190.000000  1190.000000  1190.000000  1190.000000
# mean     53.720168     0.763866         3.232773    132.153782  ...         0.387395     0.922773     1.624370     0.528571
# std       9.358203     0.424884         0.935480     18.368823  ...         0.487360     1.086337     0.610459     0.499393
# min      28.000000     0.000000         1.000000      0.000000  ...         0.000000    -2.600000     0.000000     0.000000
# 25%      47.000000     1.000000         3.000000    120.000000  ...         0.000000     0.000000     1.000000     0.000000
# 50%      54.000000     1.000000         4.000000    130.000000  ...         0.000000     0.600000     2.000000     1.000000
# 75%      60.000000     1.000000         4.000000    140.000000  ...         1.000000     1.600000     2.000000     1.000000
# max      77.000000     1.000000         4.000000    200.000000  ...         1.000000     6.200000     3.000000     1.000000
#
# [8 rows x 12 columns]

# %%
heart_data["target"].value_counts()
# Out:
# target
# 1    629
# 0    561
# Name: count, dtype: int64

# %%
'''
1 -> Defective Heart
0 -> Healty Heart 
'''
# Out:
# '\n1 -> Defective Heart\n0 -> Healty Heart \n'

# %% [markdown]
# # Splitting categorical And Numerical

# %%
x = heart_data.drop(columns="target", axis=1)
y = heart_data["target"]

# %% [markdown]
# # Spiliting the data into Train & Test

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
print(x.shape, x_train.shape, x_test.shape)
# Out:
# (1190, 11) (952, 11) (238, 11)

# %% [markdown]
# # Model Training

# %% [markdown]
# ## Logistic Regression

# %%
# Training the LR model 
lr_model = LogisticRegression()

# %%
lr_model.fit(x_train, y_train)
# Out:
# C:\Users\Dubai Computers\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %% [markdown]
# # Model Evaluation

# %%
# aaccuracy_score of training data 
train_data_pred = lr_model.predict(x_train)
# accuracy score 
train_accuracy_score = accuracy_score(train_data_pred, y_train)
# display value 
print("Accuracy score of Training Data : ", train_accuracy_score)
# Out:
# Accuracy score of Training Data :  0.8098739495798319

# %%
# aaccuracy_score of testing data 
test_data_pred = lr_model.predict(x_test)
# accuracy score 
test_accuracy_score = accuracy_score(test_data_pred, y_test)
# display value 
print("Accuracy score of Testing Data : ", test_accuracy_score)
# Out:
# Accuracy score of Testing Data :  0.8319327731092437

# %% [markdown]
# # Build Predictive System

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
input_data = ([49, 0, 3, 160, 180, 0, 0, 156, 0, 1.0, 2])

# change input data into numpy array 
input_data_as_numpy_array = np.asarray(input_data)

# reshape the numpy array , as we are prrediction for only on instance 
input_data_reshaped = input_data_as_numpy_array.reshape(1, -1)

prediction = lr_model.predict(input_data_reshaped)
print(prediction)

if (prediction[0] == 0):
    print("The Person does not have Heart Disease")
else:
    print("The Person Has Heart Disease")
# Out:
# [0]
# The Person does not have Heart Disease

# %%
print("Model Coefficients:", lr_model.coef_)
# Out:
# Model Coefficients: [[ 4.42629141e-04  9.97391250e-01  5.94019156e-01 -6.36784795e-03
#   -2.66556583e-03  8.31813003e-01  7.79397687e-02 -2.37143087e-02
#    1.06003777e+00  4.42606107e-01  9.40686016e-01]]

# %%
from sklearn.metrics import confusion_matrix
print(confusion_matrix(y_test, lr_model.predict(x_test)))
# Out:
# [[ 86  21]
#  [ 19 112]]

# %% [markdown]
# # Random Forest Model

# %%
rfr_model = RandomForestClassifier(n_estimators=100, random_state=42)

# %%
rfr_model.fit(x_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
# aaccuracy_score of testing data 
test_data_pred = rfr_model.predict(x_test)
# accuracy score 
test_accuracy_score = accuracy_score(test_data_pred, y_test)
# display value 
print("Accuracy score of Testing Data : ", test_accuracy_score)
# Out:
# Accuracy score of Testing Data :  0.9453781512605042

# %%
input_data = ([49, 0, 3, 160, 180, 0, 0, 156, 0, 1.0, 2])

# change input data into numpy array 
input_data_as_numpy_array = np.asarray(input_data)

# reshape the numpy array , as we are prrediction for only on instance 
input_data_reshaped = input_data_as_numpy_array.reshape(1, -1)

prediction = rfr_model.predict(input_data_reshaped)
print(prediction)

if (prediction[0] == 0):
    print("The Person does not have Heart Disease")
else:
    print("The Person Has Heart Disease")
# Out:
# [1]
# The Person Has Heart Disease

# %% [markdown]
# # Save the Model

# %%
import joblib
# name 
filename ="Lr Heart Disease Prediction.pkl"
joblib.dump(lr_model, filename)
# Out:
# ['Lr Heart Disease Prediction.pkl']

# %%
import joblib
# name 
filename =" RFClassifier Heart Disease Prediction.pkl"
joblib.dump(lr_model, filename)
# Out:
# [' RFClassifier Heart Disease Prediction.pkl']
